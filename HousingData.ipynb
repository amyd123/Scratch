# %% [markdown]
# <a href="https://colab.research.google.com/github/amyd123/Scratch/blob/master/HousingData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import requests

# %%
#This is the data from the Federal LIHTC program.

lihtcs = pd.read_csv ('https://raw.githubusercontent.com/amyd123/Scratch/master/LIHTCPUB.csv', encoding= 'ISO-8859–1')
# from https://lihtc.huduser.gov/

#print(lihtcs.head)
#lihtcs.dtypes

lihtcs[(lihtcs.proj_cty == "Long Beach") & (lihtcs.proj_st == "CA")]

#lb_lihtcs = pd.DataFrame(lihtcs) 
#print(lb_lihtcs.head)
# print (lb_lihtcs)
# Out:
#            hud_id                           project  ...         z yrmisflg
# 2246  CAA00000129            LONG BEACH & 21ST APTS  ...  0.556231        0
# 2639  CAA19920180                PACIFIC COURT APTS  ...  0.555859        0
# 2747  CAA19940040                 BEECHWOOD TERRACE  ...  0.556024        0
# 2820  CAA19940494                   CAMBRIDGE PLACE  ...  0.556546        0
# 2909  CAA19950100                  SEA GATE VILLAGE  ...  0.556067        0
# 3337  CAA19990530              SPRINGDALE WEST APTS  ...  0.556467        0
# 3541  CAA20000665              VILLAGES AT CABRILLO  ...  0.556151        0
# 3809  CAA20020340                      PARWOOD APTS  ...  0.557101        0
# 4042  CAA20040075                  CASA DE CABRILLO  ...  0.556199        0
# 4071  CAA20040220         GRISHAM COMMUNITY HOUSING  ...  0.556948        0
# 4282  CAA20050480                PLYMOUTH WEST APTS  ...  0.555861        0
# ...

# %%
hud_props = pd.read_csv ('https://raw.githubusercontent.com/amyd123/Scratch/master/activeportfoliopropdata.csv', encoding= 'ISO-8859–1')
# from https://www.hud.gov/program_offices/housing/mfh/presrv/mfhpreservation

#print(hud_props.head(5))
# print(hud_props.shape)

hud_props.dtypes

hud_props[(hud_props.city_name_text == "LONG BEACH") & (hud_props.state_code == "CA")]

# hud_lb_props = pd.DataFrame(hud_props)
# Out:
#       ï»¿hub_name_text  ... is_sec8_other_sub_rehab_ind
# 18022    San Francisco  ...                           N
# 18024              OHP  ...                           N
# 18031    San Francisco  ...                           N
# 18032    San Francisco  ...                           N
# 18033    San Francisco  ...                           N
# 18034    San Francisco  ...                           N
# 18035    San Francisco  ...                           N
# 18036    San Francisco  ...                           N
# 18037    San Francisco  ...                           N
# 18038    San Francisco  ...                           N
# 18039    San Francisco  ...                           N
# 18040    San Francisco  ...                           N
# 18041    San Francisco  ...                           N
# 18042    San Francisco  ...                           N
# 18043    San Francisco  ...                           N
# 18044    San Francisco  ...                           N
# ...
